# %% [markdown]
# 🧠 Day 18: Unsupervised Learning with Clustering (KMeans)
#
# Unsupervised = No labels → The algorithm finds patterns in the data itself (great for discovering structure or grouping users/customers/data points).

# %% [markdown]
# 📘 What You’ll Learn:
# What clustering is
#
# Use KMeans for unsupervised learning
#
# Visualize clusters
#
# Understand real-world use cases (market segmentation, recommendation engines, etc.)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 🔧 Step 1: Load and Prepare the Data

# %%
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df = df.dropna()
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
X = df[['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 🔮 Step 2: Fit KMeans Clustering

# %%
kmeans = KMeans(n_clusters = 3 , random_state= 42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Adding cluster labels
df['cluster'] = kmeans.labels_

# %%
# 📈 Step 3: Visualize the Clusters

sns.scatterplot(data = df, x = 'flipper_length_mm', y = "bill_depth_mm", hue = "cluster", palette = "Set2")
plt.title("KMeans clusters of Penguins")
plt.show()

# %%
####Exercise###########

# %%
df2 = sns.load_dataset("taxis")

# %%
df2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df2.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df2.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
df2.shape
# Out:
# (6341, 14)

# %%
df2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
X = df2[["distance", "fare","tip","tolls", "total"]]

# %%
scaler2 = StandardScaler()

# %%
scaled = scaler2.fit_transform(X)

# %%
kmeans = KMeans(n_clusters = 3, random_state = 42)
kmeans.fit(scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df2.loc[:,"cluster"] = kmeans.labels_

# %%
sns.scatterplot(x = "distance", y = "total", data = df2, hue = "cluster", palette = "Set3")
plt.title("KMeans Clustering of Taxis.")
plt.show()

# %%
df2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough  cluster
# 0    UN/Turtle Bay South      Manhattan       Manhattan        1
# ...

# %%
### Customer Segmentation ####

# %%
# Simulated customer data
data = {
    "CustomerID": range(1, 11),
    "Age": [19, 21, 20, 23, 31, 45, 40, 32, 28, 35],
    "Annual_Income": [15, 18, 20, 22, 50, 85, 70, 55, 48, 60],
    "Spending_Score": [39, 81, 6, 77, 40, 5, 10, 60, 48, 30]
}

# %%
df3 = pd.DataFrame(data)
df3.head()
# Out:
#    CustomerID  Age  Annual_Income  Spending_Score
# 0           1   19             15              39
# 1           2   21             18              81
# 2           3   20             20               6
# 3           4   23             22              77
# 4           5   31             50              40

# %%
features = ["Age", "Annual_Income", "Spending_Score"]
X = df3[features]

# %%
scaler3 = StandardScaler()

# %%
x_Scaled = scaler3.fit_transform(X)

# %%
kmeans = KMeans(n_clusters = 3, random_state = 42)
df3["Cluster"] = kmeans.fit_predict(x_Scaled)

# %%
sns.scatterplot(x = "Annual_Income", y = "Spending_Score", data = df3, palette = "Set2", hue = "Cluster", s = 100)
plt.title("Customer Segmentation")
plt.xlabel("Annual Income {$}")
plt.ylabel("Spending_Score")
plt.show()
